# %%
# %autosave 120
import pandas as pd 
import numpy as np
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# ## Importing the data

# %%
df_raw = pd.read_csv('NBA_Season_Data.csv')

# %%
df = df_raw.dropna(subset=['Height']) 
df = df[df.Height != 0]

# %%
df
# Out:
#          Year   Tm              Player   Age     G      MP   PER    TS%  \
# 0      1978.0  NOJ      Truck Robinson  26.0  82.0  3638.0  15.7  0.481
# 1      1978.0  BUF         Randy Smith  29.0  82.0  3314.0  19.1  0.521
# 2      1978.0  WSB         Elvin Hayes  32.0  81.0  3246.0  17.1  0.489
# 3      1978.0  BOS         Dave Cowens  29.0  77.0  3215.0  18.6  0.533
# 4      1978.0  NYK          Bob McAdoo  26.0  79.0  3182.0  22.0  0.567
# 5      1978.0  NJN        Bernard King  21.0  79.0  3092.0  17.3  0.511
# 6      1978.0  CHI       Artis Gilmore  28.0  82.0  3067.0  23.5  0.604
# 7      1978.0  DEN      David Thompson  23.0  80.0  3025.0  23.2  0.578
# 8      1978.0  GSW          Rick Barry  33.0  82.0  3024.0  20.9  0.509
# 9      1978.0  IND        Ricky Sobers  25.0  79.0  3019.0  15.4  0.514
# 10     1978.0  KCK        Scott Wedman  25.0  81.0  2961.0  15.9  0.550
# 11     1978.0  GSW          Phil Smith  25.0  82.0  2940.0  16.5  0.522
# ...

# %%
print(df.shape)
# Out:
# (17248, 109)

# %%
df.hist(column='Height', bins=20)
# plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C3157F7780>]],
#       dtype=object)

# %%
df['Height'].describe()
# Out:
# count    17248.000000
# mean        78.891350
# std          3.695711
# min         63.000000
# 25%         76.000000
# 50%         79.000000
# 75%         82.000000
# max         91.000000
# Name: Height, dtype: float64

# %%
df['Height'].median()
# Out:
# 79.0

# %%
df['Height'].mode()
# Out:
# 0    81.0
# dtype: float64
